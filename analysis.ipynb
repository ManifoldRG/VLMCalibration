# %%
import pandas as pd

# %%
df1 = pd.read_csv('records_test_full_gemma.csv', index_col=0)
# df2 = pd.read_csv('records_train_full_gemma1.csv', index_col=0)

# df = pd.concat([df1, df2], axis=0).drop_duplicates(subset=['question'])
# df.to_csv('records_train_full_gemma.csv')
df1
# Out:
#                                                question  \
# 0     James decides to run 3 sprints 3 times a week....
# 1     A robe takes 2 bolts of blue fiber and half th...
# 2     Janet’s ducks lay 16 eggs per day. She eats th...
# 3     Eliza's rate per hour for the first 40 hours s...
# 4     Every day, Wendi feeds each of her chickens th...
# ...                                                 ...
# 1314  Henry and 3 of his friends order 7 pizzas for ...
# 1315  There are some oranges in a basket. Ana spends...
# 1316  Mark's car breaks down and he needs to get a n...
# 1317  John had a son James when he was 19.  James is...
# 1318  Farmer Brown has 20 animals on his farm, all e...
#
#                                                response  answer    p_true  \
# 0     Here's how to solve the problem:\n\n* **Meters...     540  0.999996
# 1     Here's how to solve the problem:\n\n* **White ...       3  0.999999
# ...
